# %%
import qiskit
import qiskit_aer

# %%
qiskit.__version__
# Out:
# '1.4.2'

# %%
#if want to use the REAL IBM Quantum Computer Resource
#from qiskit_ibm_runtim import QiskitRuntimeService
#service = QiskitRuntimeService(channel='ibm_quantum', # ibm cloud 
#                               token = token here)

# if want to run back to back, no need to declare token because already saved
#QiskitRuntimeService.save_account(channel='ibm_quantum', 
#                                 token = token here)

# %%
# this one refer to the ibm.quantum website, then chose what quantum resource you want
# backend = service.backend(name = "ibm_brisbane")
