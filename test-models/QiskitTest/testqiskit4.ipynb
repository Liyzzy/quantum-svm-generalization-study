# %% [markdown]
# ## Transverse field Ising model to demo primitives

# %%
# Sampler Primitive - returns shot by shot strings sampled from the probability distribution of the quantum state prepared on the device

from qiskit import QuantumCircuit
from qiskit.circuit.library import YGate, UnitaryGate

def generate_1d_tfim_circuit(num_qubits, num_trotter_steps, rx_angle)
    qc = QuantumCircuit(num_qubits)
